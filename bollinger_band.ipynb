# %%
import finterstellar as fs

# %%
# Get Price
symbol = 'COST'
df = fs.get_price(symbol, start_date='2022-05-31', end_date='2025-05-31')

# %%
fs.draw_chart(df, right=symbol)

# %%
fs.bollinger(df, w=20, k=2)
df.tail()
# Out:
#                COST   center  sigma       ub     lb
# 2025-05-23 1,008.50 1,009.07  15.01 1,039.08 979.06
# 2025-05-27 1,017.79 1,011.10  13.10 1,037.30 984.89
# 2025-05-28 1,013.14 1,012.23  12.16 1,036.56 987.90
# 2025-05-29 1,008.74 1,013.01  11.35 1,035.72 990.30
# 2025-05-30 1,040.18 1,015.13  12.28 1,039.69 990.57

# %%
fs.draw_band_chart(df)

# %%
fs.band_to_signal(df, buy='A', sell='B')
# Out:
# 2022-05-31    zero
# 2022-06-01    zero
# 2022-06-02    zero
# 2022-06-03    zero
# 2022-06-06    zero
#               ...
# 2025-05-23    zero
# 2025-05-27    zero
# 2025-05-28    zero
# 2025-05-29    zero
# 2025-05-30     buy
# Name: trade, Length: 753, dtype: object

# %%
fs.position(df)
# Out:
# 2022-05-31
# 2022-06-01    zz
# 2022-06-02    zz
# 2022-06-03    zz
# 2022-06-06    zz
#               ..
# 2025-05-23    zz
# 2025-05-27    zz
# 2025-05-28    zz
# 2025-05-29    zz
# 2025-05-30    zl
# Name: position, Length: 753, dtype: object

# %%
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.02)
fs.draw_trade_results(df)
# Out:
# CAGR: -2.46%
# Accumulated return: -7.01%
# Average return: -0.29%
# Benchmark return : 131.44%
# Number of trades: 25
# Number of win: 11
# Hit ratio: 44.00%
# Investment period: 2.9yrs
# Sharpe ratio: -0.48
# MDD: -15.47%
# Benchmark MDD: -19.60%

# %%
fs.band_to_signal(df, buy='D', sell='B')
# Out:
# 2022-06-28    zero
# 2022-06-29    zero
# 2022-06-30    zero
# 2022-07-01    zero
# 2022-07-05    zero
#               ...
# 2025-05-23    zero
# 2025-05-27    zero
# 2025-05-28    zero
# 2025-05-29    zero
# 2025-05-30    zero
# Name: trade, Length: 734, dtype: object

# %%
fs.position(df)
# Out:
# 2022-06-28
# 2022-06-29    zz
# 2022-06-30    zz
# 2022-07-01    zz
# 2022-07-05    zz
#               ..
# 2025-05-23    zz
# 2025-05-27    zz
# 2025-05-28    zz
# 2025-05-29    zz
# 2025-05-30    zz
# Name: position, Length: 734, dtype: object

# %%
fs.evaluate(df, cost=.001)
fs.performance(df, rf_rate=0.02)
fs.draw_trade_results(df)
# Out:
# CAGR: 1.78%
# Accumulated return: 5.28%
# Average return: 0.88%
# Benchmark return : 131.44%
# Number of trades: 6
# Number of win: 4
# Hit ratio: 66.67%
# Investment period: 2.9yrs
# Sharpe ratio: -0.02
# MDD: -7.64%
# Benchmark MDD: -19.60%

# %%
# Get Price
df = fs.get_price('^KS200', start_date='2022-05-31', end_date='2025-05-31')

# %%
df
# Out:
#             ^KS200
# 2022-05-31  354.54
# 2022-06-02  350.51
# 2022-06-03  352.01
# 2022-06-07  345.67
# 2022-06-08  346.22
# ...            ...
# 2025-05-26  352.11
# 2025-05-27  351.28
# 2025-05-28  356.36
# 2025-05-29  363.08
# 2025-05-30  359.62
#
# [734 rows x 1 columns]
